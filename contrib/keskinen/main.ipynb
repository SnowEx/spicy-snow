# %%
from pathlib import Path
import numpy as np
import pandas as pd
import xarray as xr

# %%
d_dir = Path('~/scratch/SnowEx-Data').expanduser()
sub_dir = Path('/bsuhome/zacharykeskinen/spicy-snow/SnowEx-Data/')
for fp in d_dir.glob('*.nc'):
    ds = xr.open_dataset(fp)
    ds = ds[['lidar-sd', 'lidar-vh','lidar-dem','snow_depth', 'wet_snow', 'spatial_ref']]
    ds.to_netcdf(sub_dir.joinpath(fp.stem).with_suffix('.nc'))
    # sub = xr.open_dataset(sub_dir.joinpath(fp.stem).with_suffix('.sub.nc'))

# %%
ds = xr.open_dataset('/bsuhome/zacharykeskinen/spicy-snow/SnowEx-Data/Banner_2020-02-18.sub.nc')

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:         (y: 148, x: 190, time: 58)
# Coordinates:
#   * x               (x) float64 -115.3 -115.3 -115.3 ... -115.1 -115.1 -115.1
#   * y               (y) float64 44.34 44.34 44.34 44.34 ... 44.2 44.19 44.19
#   * time            (time) datetime64[ns] 2019-08-05T01:35:54 ... 2020-03-02T...
#     flight_dir      (time) object ...
#     platform        (time) object ...
#     relative_orbit  (time) float64 ...
#     absolute_orbit  (time) float64 ...
#     projection      int64 ...
# Data variables:
#     lidar-sd        (y, x) float32 ...
#     lidar-vh        (y, x) float32 ...
#     lidar-dem       (y, x) float32 ...
#     snow_depth      (y, x, time) float64 ...
#     wet_snow        (time, y, x) float32 ...
#     spatial_ref     int64 ...
# Attributes: (12/15)
#     AREA_OR_POINT:      Point
#     TIFFTAG_DATETIME:   2023:05:19 05:18:38
#     TIFFTAG_SOFTWARE:   Created with GAMMA Software www.gamma-rs.ch data2geot...
#     scale_factor:       1.0
#     add_offset:         0.0
#     resolution:         90
#     ...                 ...
#     param_C:            0.55
#     job_name:           spicy_USIDBS_2020-03-03
#     bounds:             [-115.28143275   44.19225956 -115.08677234   44.34416...
#     site:               Banner
#     site_abbrev:        USIDBS
#     lidar-flight-time:  2020-02-18
